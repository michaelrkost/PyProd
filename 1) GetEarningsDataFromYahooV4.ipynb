# %%
import sys
#================================================================
# sys.path.append("/home/michael/pycharm/pycharm-2019.2.3/debug-eggs/pydevd-pycharm.egg")
#
# import pydevd_pycharm
# pydevd_pycharm.settrace('192.168.1.200', port=2222, stdoutToServer=True, stderrToServer=True)
#================================================================

sys.path.append('/home/michael/jupyter/local-packages')

import datetime

from localUtilities.ibUtils import setup
from localUtilities.webScrape import getEarningsOnDate
from localUtilities.ibUtils import buildCsvSummary 

startTime = datetime.datetime.now()

print('Start Time: ', startTime.strftime("%Y-%m-%d %H:%M"))
# Out:
# Start Time:  2020-10-24 12:31

# %%
# Starting day of the earnings week.
startday = '2020-10-26'
startday
# Out:
# '2020-10-26'

# %%
# get earnings from Yahoo for the week of startdate
aWeeksEarningsDF = getEarningsOnDate.getEarningsForWeek(startday)
# Out:
# 1-93 of 93 results
# earningCount =  93
# Working Day:  2020-10-26
# 1-100 of 178 results
# earningCount =  178
# Working Day:  2020-10-27
# 1-100 of 319 results
# earningCount =  319
# Working Day:  2020-10-28
# 1-100 of 391 results
# earningCount =  391
# Working Day:  2020-10-29
# 1-81 of 81 results
# earningCount =  81
# Working Day:  2020-10-30
#
# Total Companies with earning:  1062
# Done...

# %%
# Add Market Data: 
#    Close Price, Last Price, Historic Volatility, Implied Volatility, Option Volume, Expected Range $ move
yahooEarningsOfInterestDF, allYahooEarningsForWeekDF = setup.addMarketData( aWeeksEarningsDF, startday)
# Out:
# 1061 | adding market data for:  AGRX 	Implied Vol:   1.30
# 1060 | adding market data for:  AGNCP 	Implied Vol:   0.00
# 1059 | adding market data for:  ARI 	Implied Vol:   0.43
# 1058 | adding market data for:  AMKR 	Implied Vol:   0.64
# 1057 | adding market data for:  ASPS 	Implied Vol:   0.78
# 1056 | adding market data for:  ARE 	Implied Vol:   0.28
# 1055 | adding market data for:  ACC 	Implied Vol:   0.38
# 1054 | adding market data for:  PKG 	Implied Vol:   0.36
# 1053 | adding market data for:  CRSP 	Implied Vol:   0.72
# 1052 | adding market data for:  AJRD 	Implied Vol:   0.51
# 1051 | adding market data for:  AMG 	Implied Vol:   0.45
# 1050 | adding market data for:  AGNC 	Implied Vol:   0.27
# 1049 | adding market data for:  AROC 	Implied Vol:   0.69
# 1048 | adding market data for:  GABC 	Implied Vol:   0.00
# 1047 | adding market data for:  ARLP 	Implied Vol:   1.05
# 1046 | adding market data for:  BYD 	Implied Vol:   0.63
# 1045 | adding market data for:  CATY 	Implied Vol:   0.51
# 1044 | adding market data for:  TCBK 	Implied Vol:   0.32
# 1043 | adding market data for:  BOH 	Implied Vol:   0.38
# 1042 | adding market data for:  PWOD 	Implied Vol:   0.00
# 1041 | adding market data for:  BHLB 	Implied Vol:   0.53
# 1040 | adding market data for:  FNWB 	Implied Vol:   0.00
# 1039 | adding market data for:  NBTB 	Implied Vol:   0.00
# 1038 | adding market data for:  BMRC 	Implied Vol:   0.00
# 1037 | adding market data for:  IBTX 	Implied Vol:   0.37
# 1036 | adding market data for:  HBCP 	Implied Vol:   0.00
# 1035 | adding market data for:  CBU 	Implied Vol:   0.40
# 1034 | adding market data for:  FIBK 	Implied Vol:   0.31
# 1033 | adding market data for:  TRIB 	Implied Vol:   1.40
# 1032 | adding market data for:  JBSS 	Implied Vol:   0.41
# 1031 | adding market data for:  PMBC 	Implied Vol:   0.00
# 1030 | adding market data for:  NRIM 	Implied Vol:   0.00
# 1029 | adding market data for:  FRBA 	Implied Vol:   0.00
# 1028 | adding market data for:  BRO 	Implied Vol:   0.29
# 1027 | adding market data for:  RBB 	Implied Vol:   0.00
# 1026 | adding market data for:  LKFN 	Implied Vol:   0.38
# 1025 | adding market data for:  CVLG 	Implied Vol:   0.92
# 1024 | adding market data for:  PRK 	Implied Vol:   0.00
# 1023 | adding market data for:  NRZ 	Implied Vol:   0.54
# 1022 | adding market data for:  FEDU 	Implied Vol:   0.00
# 1021 | adding market data for:  FEDU 	Implied Vol:   0.00
# 1020 | adding market data for:  FIX 	Implied Vol:   0.52
# 1019 | adding market data for:  CHGG 	Implied Vol:   0.70
# 1018 | adding market data for:  OTIS 	Implied Vol:   0.36
# 1017 | adding market data for:  SI 	Implied Vol:   0.00
# 1016 | adding market data for:  SI 	Implied Vol:   0.00
# 1015 | adding market data for:  ROIC 	Implied Vol:   0.56
# 1014 | adding market data for:  TCFCP 	Implied Vol:   0.00
# 1013 | adding market data for:  PCH 	Implied Vol:   0.37
# 1012 | adding market data for:  CR 	Implied Vol:   0.41
# 1011 | adding market data for:  CINF 	Implied Vol:   0.45
# 1010 | adding market data for:  MC 	Implied Vol:   0.38
# 1009 | adding market data for:  SSD 	Implied Vol:   0.46
# 1008 | adding market data for:  SANM 	Implied Vol:   0.47
# 1007 | adding market data for:  SMPL 	Implied Vol:   0.56
# 1006 | adding market data for:  TCF 	Implied Vol:   0.45
# 1005 | adding market data for:  FBK 	Implied Vol:   0.41
# 1004 | adding market data for:  DOFSQ 	Implied Vol:   0.00
# 1003 | adding market data for:  DO 	Implied Vol:   0.00
# 1002 | adding market data for:  PETS 	Implied Vol:   0.71
# 1001 | adding market data for:  KREF 	Implied Vol:   0.00
# 1000 | adding market data for:  HTLFP 	Implied Vol:   0.00
# 999 | adding market data for:  FLXS 	Implied Vol:   0.00
# 998 | adding market data for:  HTLF 	Implied Vol:   0.52
# 997 | adding market data for:  FFIV 	Implied Vol:   0.54
# 996 | adding market data for:  PFG 	Implied Vol:   0.39
# 995 | adding market data for:  MEDS 	Implied Vol:   0.00
# 994 | adding market data for:  MEDS 	Implied Vol:   0.00
# 993 | adding market data for:  TNET 	Implied Vol:   0.54
# 992 | adding market data for:  KOP 	Implied Vol:   0.71
# 991 | adding market data for:  CKH 	Implied Vol:   0.00
# 990 | adding market data for:  MEDP 	Implied Vol:   0.57
# 989 | adding market data for:  HMST 	Implied Vol:   0.40
# 988 | adding market data for:  OMF 	Implied Vol:   0.47
# 987 | adding market data for:  HSTM 	Implied Vol:   0.47
# 986 | adding market data for:  HSII 	Implied Vol:   0.00
# 985 | adding market data for:  HLIT 	Implied Vol:   0.74
# 984 | adding market data for:  HAS 	Implied Vol:   0.61
# 983 | adding market data for:  LXFR 	Implied Vol:   0.00
# 982 | adding market data for:  HCA 	Implied Vol:   0.48
# 981 | adding market data for:  MNOV 	Implied Vol:   0.00
# 980 | adding market data for:  NOV 	Implied Vol:   0.74
# 979 | adding market data for:  LBYYQ 	Implied Vol:   0.00
# 978 | adding market data for:  QTS 	Implied Vol:   0.32
# 977 | adding market data for:  TWLO 	Implied Vol:   0.76
# 976 | adding market data for:  VRNS 	Implied Vol:   0.44
# 975 | adding market data for:  KNL 	Implied Vol:   0.65
# 974 | adding market data for:  UFI 	Implied Vol:   0.00
# 973 | adding market data for:  IVAC 	Implied Vol:   0.00
# 972 | adding market data for:  LRN 	Implied Vol:   0.92
# 971 | adding market data for:  TBI 	Implied Vol:   0.57
# 970 | adding market data for:  NXPI 	Implied Vol:   0.49
# 969 | adding market data for:  WSR 	Implied Vol:   0.40
# 968 | adding market data for:  TWOU 	Implied Vol:   0.67
# 967 | adding market data for:  MMM 	Implied Vol:   0.36
# 966 | adding market data for:  BGFV 	Implied Vol:   1.37
# 965 | adding market data for:  BLX 	Implied Vol:   0.48
# 964 | adding market data for:  ABG 	Implied Vol:   0.61
# 963 | adding market data for:  AWI 	Implied Vol:   0.40
# 962 | adding market data for:  AFL 	Implied Vol:   0.34
# 961 | adding market data for:  AWRE 	Implied Vol:   0.00
# 960 | adding market data for:  ARCC 	Implied Vol:   0.27
# 959 | adding market data for:  AGYS 	Implied Vol:   0.40
# 958 | adding market data for:  APAM 	Implied Vol:   0.44
# 957 | adding market data for:  JBLU 	Implied Vol:   0.65
# 956 | adding market data for:  AKAM 	Implied Vol:   0.49
# 955 | adding market data for:  LLY 	Implied Vol:   0.36
# 954 | adding market data for:  ATEN 	Implied Vol:   0.77
# 953 | adding market data for:  AAT 	Implied Vol:   0.00
# 952 | adding market data for:  ACCO 	Implied Vol:   0.58
# 951 | adding market data for:  AHC 	Implied Vol:   0.00
# 950 | adding market data for:  GLPI 	Implied Vol:   0.38
# 949 | adding market data for:  AHC 	Implied Vol:   0.00
# 948 | adding market data for:  LH 	Implied Vol:   0.34
# 947 | adding market data for:  AMD 	Implied Vol:   0.77
# 946 | adding market data for:  ADSW 	Implied Vol:   0.04
# 945 | adding market data for:  AHT 	Implied Vol:   2.50
# 944 | adding market data for:  AUDC 	Implied Vol:   0.66
# 943 | adding market data for:  IBCP 	Implied Vol:   0.35
# 942 | adding market data for:  PPBI 	Implied Vol:   0.47
# 941 | adding market data for:  BDGE 	Implied Vol:   0.29
# 940 | adding market data for:  BXP 	Implied Vol:   0.41
# 939 | adding market data for:  TPB 	Implied Vol:   0.67
# 938 | adding market data for:  BHLB 	Implied Vol:   0.53
# 937 | adding market data for:  JBT 	Implied Vol:   0.00
# 936 | adding market data for:  CCBG 	Implied Vol:   0.00
# 935 | adding market data for:  SBCF 	Implied Vol:   0.51
# 934 | adding market data for:  LBC 	Implied Vol:   0.00
# 933 | adding market data for:  SBKK 	Implied Vol:   0.00
# 932 | adding market data for:  RCKY 	Implied Vol:   0.00
# 931 | adding market data for:  RCKY 	Implied Vol:   0.00
# 930 | adding market data for:  DCOM 	Implied Vol:   0.00
# 929 | adding market data for:  BUSE 	Implied Vol:   0.00
# 928 | adding market data for:  SWK 	Implied Vol:   0.42
# 927 | adding market data for:  JBSS 	Implied Vol:   0.41
# 926 | adding market data for:  SALT 	Implied Vol:   0.00
# 925 | adding market data for:  HTBI 	Implied Vol:   0.00
# 924 | adding market data for:  FRBA 	Implied Vol:   0.00
# 923 | adding market data for:  RBB 	Implied Vol:   0.00
# 922 | adding market data for:  CVLG 	Implied Vol:   0.92
# 921 | adding market data for:  MASI 	Implied Vol:   0.39
# 920 | adding market data for:  UMBF 	Implied Vol:   0.36
# 919 | adding market data for:  CAC 	Implied Vol:   0.00
# 918 | adding market data for:  CAC 	Implied Vol:   0.00
# 917 | adding market data for:  TEX 	Implied Vol:   0.57
# 916 | adding market data for:  CNC 	Implied Vol:   0.48
# 915 | adding market data for:  CMI 	Implied Vol:   0.36
# 914 | adding market data for:  CB 	Implied Vol:   0.35
# 913 | adding market data for:  SITC 	Implied Vol:   0.90
# 912 | adding market data for:  SMED 	Implied Vol:   0.77
# 911 | adding market data for:  MRK 	Implied Vol:   0.30
# 910 | adding market data for:  CROX 	Implied Vol:   0.71
# 909 | adding market data for:  RRD 	Implied Vol:   1.29
# 908 | adding market data for:  RNST 	Implied Vol:   0.42
# 907 | adding market data for:  RGS 	Implied Vol:   0.93
# 906 | adding market data for:  FCPT 	Implied Vol:   0.00
# 905 | adding market data for:  MSM 	Implied Vol:   0.36
# 904 | adding market data for:  CSGP 	Implied Vol:   0.39
# 903 | adding market data for:  SWI 	Implied Vol:   0.51
# 902 | adding market data for:  COWN 	Implied Vol:   0.45
# 901 | adding market data for:  CYH 	Implied Vol:   1.29
# 900 | adding market data for:  FELE 	Implied Vol:   0.38
# 899 | adding market data for:  UIS 	Implied Vol:   0.57
# 898 | adding market data for:  FTV 	Implied Vol:   0.34
# 897 | adding market data for:  KTCC 	Implied Vol:   0.64
# 896 | adding market data for:  CEQP 	Implied Vol:   0.50
# 895 | adding market data for:  CAMT 	Implied Vol:   0.51
# 894 | adding market data for:  OXSQ 	Implied Vol:   0.45
# 893 | adding market data for:  DTE 	Implied Vol:   0.26
# 892 | adding market data for:  RXN 	Implied Vol:   0.37
# 891 | adding market data for:  CVLT 	Implied Vol:   0.56
# 890 | adding market data for:  CAT 	Implied Vol:   0.37
# 889 | adding market data for:  FSP 	Implied Vol:   0.00
# 888 | adding market data for:  MTDR 	Implied Vol:   0.90
# 887 | adding market data for:  RTX 	Implied Vol:   0.38
# 886 | adding market data for:  LSCC 	Implied Vol:   0.63
# 885 | adding market data for:  SHW 	Implied Vol:   0.30
# 884 | adding market data for:  QUMU 	Implied Vol:   0.00
# 883 | adding market data for:  QUMU 	Implied Vol:   0.00
# 882 | adding market data for:  SQNS 	Implied Vol:   0.00
# 881 | adding market data for:  SQNS 	Implied Vol:   0.00
# 880 | adding market data for:  MKL 	Implied Vol:   0.29
# 879 | adding market data for:  TRMK 	Implied Vol:   0.48
# 878 | adding market data for:  FFIC 	Implied Vol:   0.00
# 877 | adding market data for:  FCF 	Implied Vol:   0.37
# 876 | adding market data for:  CHRW 	Implied Vol:   0.33
# 875 | adding market data for:  WAT 	Implied Vol:   0.46
# 874 | adding market data for:  MSFT 	Implied Vol:   0.39
# 873 | adding market data for:  SKY 	Implied Vol:   0.68
# 872 | adding market data for:  CSTM 	Implied Vol:   0.75
# 871 | adding market data for:  WIRE 	Implied Vol:   0.00
# 870 | adding market data for:  CAI 	Implied Vol:   0.00
# 869 | adding market data for:  SAVA 	Implied Vol:   1.26
# 868 | adding market data for:  XRX 	Implied Vol:   0.48
# 867 | adding market data for:  DENN 	Implied Vol:   0.79
# 866 | adding market data for:  FBK 	Implied Vol:   0.41
# 865 | adding market data for:  NCR 	Implied Vol:   0.54
# 864 | adding market data for:  HAFC 	Implied Vol:   0.45
# 863 | adding market data for:  GLW 	Implied Vol:   0.45
# 862 | adding market data for:  ODFL 	Implied Vol:   0.34
# 861 | adding market data for:  DHIL 	Implied Vol:   0.00
# 860 | adding market data for:  DXCM 	Implied Vol:   0.60
# 859 | adding market data for:  HOG 	Implied Vol:   0.67
# 858 | adding market data for:  PEI 	Implied Vol:   0.00
# 857 | adding market data for:  ENPH 	Implied Vol:   1.02
# 856 | adding market data for:  EIX 	Implied Vol:   0.33
# 855 | adding market data for:  LECO 	Implied Vol:   0.37
# 854 | adding market data for:  ENVA 	Implied Vol:   0.64
# 853 | adding market data for:  ENVA 	Implied Vol:   0.64
# 852 | adding market data for:  ECL 	Implied Vol:   0.29
# 851 | adding market data for:  EQR 	Implied Vol:   0.41
# 850 | adding market data for:  KREF 	Implied Vol:   0.00
# 849 | adding market data for:  EGP 	Implied Vol:   0.00
# 848 | adding market data for:  ESI 	Implied Vol:   0.44
# 847 | adding market data for:  FSLR 	Implied Vol:   0.75
# 846 | adding market data for:  FISV 	Implied Vol:   0.44
# 845 | adding market data for:  SPFI 	Implied Vol:   0.00
# 844 | adding market data for:  SPFI 	Implied Vol:   0.00
# 843 | adding market data for:  FFWM 	Implied Vol:   0.00
# 842 | adding market data for:  FEYE 	Implied Vol:   0.83
# 841 | adding market data for:  BEN 	Implied Vol:   0.36
# 840 | adding market data for:  WDR 	Implied Vol:   0.48
# 839 | adding market data for:  SPGI 	Implied Vol:   0.33
# 838 | adding market data for:  THG 	Implied Vol:   0.35
# 837 | adding market data for:  OMC 	Implied Vol:   0.36
# 836 | adding market data for:  OI 	Implied Vol:   0.71
# 835 | adding market data for:  UNM 	Implied Vol:   0.44
# 834 | adding market data for:  PRGX 	Implied Vol:   0.00
# 833 | adding market data for:  QCRH 	Implied Vol:   0.00
# 832 | adding market data for:  HUBB 	Implied Vol:   0.00
# 831 | adding market data for:  RNR 	Implied Vol:   0.00
# 830 | adding market data for:  UVE 	Implied Vol:   0.57
# 829 | adding market data for:  ST 	Implied Vol:   0.40
# 828 | adding market data for:  HA 	Implied Vol:   0.76
# 827 | adding market data for:  HIW 	Implied Vol:   0.00
# 826 | adding market data for:  TENB 	Implied Vol:   0.62
# 825 | adding market data for:  MKTX 	Implied Vol:   0.37
# 824 | adding market data for:  MKSI 	Implied Vol:   0.00
# 823 | adding market data for:  IVZ 	Implied Vol:   0.50
# 822 | adding market data for:  LBRT 	Implied Vol:   0.78
# 821 | adding market data for:  RRR 	Implied Vol:   0.80
# 820 | adding market data for:  ROP 	Implied Vol:   0.28
# 819 | adding market data for:  LDL 	Implied Vol:   0.00
# 818 | adding market data for:  PJT 	Implied Vol:   0.00
# 817 | adding market data for:  ZYXI 	Implied Vol:   0.88
# 816 | adding market data for:  KAI 	Implied Vol:   0.31
# 815 | adding market data for:  SSTK 	Implied Vol:   0.62
# 814 | adding market data for:  MXIM 	Implied Vol:   0.36
# 813 | adding market data for:  VECO 	Implied Vol:   0.74
# 812 | adding market data for:  PFE 	Implied Vol:   0.48
# 811 | adding market data for:  JNPR 	Implied Vol:   0.63
# 810 | adding market data for:  INTEQ 	Implied Vol:   0.00
# 809 | adding market data for:  TRNS 	Implied Vol:   0.00
# 808 | adding market data for:  NXRT 	Implied Vol:   0.48
# 807 | adding market data for:  NXRT 	Implied Vol:   0.48
# 806 | adding market data for:  MSTR 	Implied Vol:   0.70
# 805 | adding market data for:  RARE 	Implied Vol:   0.59
# 804 | adding market data for:  OMCL 	Implied Vol:   0.43
# 803 | adding market data for:  MSCI 	Implied Vol:   0.39
# 802 | adding market data for:  OKE 	Implied Vol:   0.45
# 801 | adding market data for:  I 	Implied Vol:   0.00
# 800 | adding market data for:  NPK 	Implied Vol:   0.00
# 799 | adding market data for:  PII 	Implied Vol:   0.50
# 798 | adding market data for:  UFI 	Implied Vol:   0.00
# 797 | adding market data for:  SYX 	Implied Vol:   0.50
# 796 | adding market data for:  NEO 	Implied Vol:   0.61
# 795 | adding market data for:  SUM 	Implied Vol:   0.65
# 794 | adding market data for:  SHOO 	Implied Vol:   0.55
# 793 | adding market data for:  MMYT 	Implied Vol:   0.63
# 792 | adding market data for:  TX 	Implied Vol:   0.42
# 791 | adding market data for:  TRU 	Implied Vol:   0.38
# 790 | adding market data for:  EGHT 	Implied Vol:   0.63
# 789 | adding market data for:  ASGN 	Implied Vol:   0.43
# 788 | adding market data for:  AMP 	Implied Vol:   0.38
# 787 | adding market data for:  AXS 	Implied Vol:   0.39
# 786 | adding market data for:  RCII 	Implied Vol:   0.51
# 785 | adding market data for:  NLY 	Implied Vol:   0.32
# 784 | adding market data for:  AEMD 	Implied Vol:   0.00
# 783 | adding market data for:  AMSF 	Implied Vol:   0.00
# 782 | adding market data for:  ALTA 	Implied Vol:   0.00
# 781 | adding market data for:  RAIL 	Implied Vol:   1.44
# 780 | adding market data for:  ACA 	Implied Vol:   0.52
# 779 | adding market data for:  ALGT 	Implied Vol:   0.55
# 778 | adding market data for:  ANTM 	Implied Vol:   0.39
# 777 | adding market data for:  ALSN 	Implied Vol:   0.38
# 776 | adding market data for:  AZPN 	Implied Vol:   0.57
# 775 | adding market data for:  AMAL 	Implied Vol:   0.00
# 774 | adding market data for:  AVID 	Implied Vol:   0.76
# 773 | adding market data for:  AVID 	Implied Vol:   0.76
# 772 | adding market data for:  AEGN 	Implied Vol:   0.00
# 771 | adding market data for:  ATNI 	Implied Vol:   0.00
# 770 | adding market data for:  AVTR 	Implied Vol:   0.50
# 769 | adding market data for:  AFG 	Implied Vol:   0.38
# 768 | adding market data for:  ADP 	Implied Vol:   0.33
# 767 | adding market data for:  ACNB 	Implied Vol:   0.00
# 766 | adding market data for:  ACIA 	Implied Vol:   0.24
# 765 | adding market data for:  KYN 	Implied Vol:   0.48
# 764 | adding market data for:  ALRS 	Implied Vol:   0.00
# 763 | adding market data for:  AIN 	Implied Vol:   0.00
# 762 | adding market data for:  AXTI 	Implied Vol:   0.90
# 761 | adding market data for:  ORLY 	Implied Vol:   0.35
# 760 | adding market data for:  AMED 	Implied Vol:   0.48
# 759 | adding market data for:  AR 	Implied Vol:   0.98
# 758 | adding market data for:  AMGN 	Implied Vol:   0.34
# 757 | adding market data for:  AIT 	Implied Vol:   0.00
# 756 | adding market data for:  SEE 	Implied Vol:   0.37
# 755 | adding market data for:  MAA 	Implied Vol:   0.28
# 754 | adding market data for:  ARES 	Implied Vol:   0.44
# 753 | adding market data for:  AM 	Implied Vol:   0.46
# 752 | adding market data for:  AVB 	Implied Vol:   0.33
# 751 | adding market data for:  AVT 	Implied Vol:   0.42
# 750 | adding market data for:  SAVE 	Implied Vol:   0.85
# 749 | adding market data for:  ALG 	Implied Vol:   0.00
# 748 | adding market data for:  ALIM 	Implied Vol:   0.00
# 747 | adding market data for:  MBIN 	Implied Vol:   0.00
# 746 | adding market data for:  BCRHF 	Implied Vol:   0.00
# 745 | adding market data for:  ISBC 	Implied Vol:   0.48
# 744 | adding market data for:  HBMD 	Implied Vol:   0.00
# 743 | adding market data for:  BDGE 	Implied Vol:   0.29
# 742 | adding market data for:  SYBT 	Implied Vol:   0.00
# 741 | adding market data for:  BAS 	Implied Vol:   0.00
# 740 | adding market data for:  KLDO 	Implied Vol:   0.00
# 739 | adding market data for:  BHR 	Implied Vol:   0.90
# 738 | adding market data for:  BG 	Implied Vol:   0.43
# 737 | adding market data for:  RBC 	Implied Vol:   0.46
# 736 | adding market data for:  CUBI 	Implied Vol:   0.61
# 735 | adding market data for:  DIN 	Implied Vol:   0.74
# 734 | adding market data for:  FBHS 	Implied Vol:   0.40
# 733 | adding market data for:  BCRH 	Implied Vol:   0.00
# 732 | adding market data for:  BSX 	Implied Vol:   0.46
# 731 | adding market data for:  BXC 	Implied Vol:   1.23
# 730 | adding market data for:  BRKL 	Implied Vol:   0.35
# 729 | adding market data for:  PSB 	Implied Vol:   0.00
# 728 | adding market data for:  OBNK 	Implied Vol:   0.00
# 727 | adding market data for:  TUP 	Implied Vol:   1.22
# 726 | adding market data for:  LARK 	Implied Vol:   0.00
# 725 | adding market data for:  BCPC 	Implied Vol:   0.00
# 724 | adding market data for:  CVCY 	Implied Vol:   0.00
# 723 | adding market data for:  BASX 	Implied Vol:   0.00
# 722 | adding market data for:  BGCP 	Implied Vol:   0.62
# 721 | adding market data for:  BKU 	Implied Vol:   0.50
# 720 | adding market data for:  NTB 	Implied Vol:   0.00
# 719 | adding market data for:  SBT 	Implied Vol:   0.00
# 718 | adding market data for:  BDC 	Implied Vol:   0.57
# 717 | adding market data for:  GWB 	Implied Vol:   0.65
# 716 | adding market data for:  BX 	Implied Vol:   0.35
# 715 | adding market data for:  BOOT 	Implied Vol:   0.71
# 714 | adding market data for:  FGBI 	Implied Vol:   0.00
# 713 | adding market data for:  BWFG 	Implied Vol:   0.00
# 712 | adding market data for:  NYCB 	Implied Vol:   0.35
# 711 | adding market data for:  EAT 	Implied Vol:   0.80
# 710 | adding market data for:  HBNC 	Implied Vol:   0.00
# 709 | adding market data for:  PB 	Implied Vol:   0.00
# 708 | adding market data for:  BA 	Implied Vol:   0.55
# 707 | adding market data for:  BLKB 	Implied Vol:   0.59
# 706 | adding market data for:  BHE 	Implied Vol:   0.00
# 705 | adding market data for:  FOXF 	Implied Vol:   0.54
# 704 | adding market data for:  MIC 	Implied Vol:   0.43
# 703 | adding market data for:  GE 	Implied Vol:   0.71
# 702 | adding market data for:  IO 	Implied Vol:   0.00
# 701 | adding market data for:  NESR 	Implied Vol:   0.00
# 700 | adding market data for:  CONE 	Implied Vol:   0.36
# 699 | adding market data for:  CTSH 	Implied Vol:   0.35
# 698 | adding market data for:  CBTX 	Implied Vol:   0.00
# 697 | adding market data for:  CDE 	Implied Vol:   0.82
# 696 | adding market data for:  CTO 	Implied Vol:   0.00
# 695 | adding market data for:  SIX 	Implied Vol:   0.76
# 694 | adding market data for:  KLAC 	Implied Vol:   0.48
# 693 | adding market data for:  MPX 	Implied Vol:   0.68
# 692 | adding market data for:  MPX 	Implied Vol:   0.68
# 691 | adding market data for:  FRME 	Implied Vol:   0.00
# 690 | adding market data for:  UVSP 	Implied Vol:   0.00
# 689 | adding market data for:  NGHC 	Implied Vol:   0.00
# 688 | adding market data for:  KRC 	Implied Vol:   0.35
# 687 | adding market data for:  F 	Implied Vol:   0.59
# 686 | adding market data for:  CHDN 	Implied Vol:   0.51
# 685 | adding market data for:  CODI 	Implied Vol:   0.36
# 684 | adding market data for:  NDLS 	Implied Vol:   0.63
# 683 | adding market data for:  WDC 	Implied Vol:   0.65
# 682 | adding market data for:  GHM 	Implied Vol:   0.00
# 681 | adding market data for:  RYI 	Implied Vol:   0.00
# 680 | adding market data for:  CVEO 	Implied Vol:   0.00
# 679 | adding market data for:  CVEO 	Implied Vol:   0.00
# 678 | adding market data for:  SF 	Implied Vol:   0.41
# 677 | adding market data for:  HVT 	Implied Vol:   0.50
# 676 | adding market data for:  UCTT 	Implied Vol:   0.75
# 675 | adding market data for:  UCTT 	Implied Vol:   0.75
# 674 | adding market data for:  IART 	Implied Vol:   0.41
# 673 | adding market data for:  CNMD 	Implied Vol:   0.53
# 672 | adding market data for:  CHEF 	Implied Vol:   0.81
# 671 | adding market data for:  CERN 	Implied Vol:   0.32
# 670 | adding market data for:  DMRC 	Implied Vol:   0.90
# 669 | adding market data for:  ETR 	Implied Vol:   0.25
# 668 | adding market data for:  CRTO 	Implied Vol:   0.68
# 667 | adding market data for:  DMRC 	Implied Vol:   0.90
# 666 | adding market data for:  PLXS 	Implied Vol:   0.00
# 665 | adding market data for:  MCRI 	Implied Vol:   0.51
# 664 | adding market data for:  GHC 	Implied Vol:   0.00
# 663 | adding market data for:  YUMC 	Implied Vol:   0.37
# 662 | adding market data for:  CASA 	Implied Vol:   0.89
# 661 | adding market data for:  CASA 	Implied Vol:   0.89
# 660 | adding market data for:  SPWR 	Implied Vol:   1.34
# 659 | adding market data for:  SCI 	Implied Vol:   0.33
# 658 | adding market data for:  CSV 	Implied Vol:   0.56
# 657 | adding market data for:  NE 	Implied Vol:   0.00
# 656 | adding market data for:  NGHCP 	Implied Vol:   0.00
# 655 | adding market data for:  SEB 	Implied Vol:   0.00
# 654 | adding market data for:  CIX 	Implied Vol:   0.00
# 653 | adding market data for:  MAS 	Implied Vol:   0.33
# 652 | adding market data for:  CFFN 	Implied Vol:   0.00
# 651 | adding market data for:  CUZ 	Implied Vol:   0.00
# 650 | adding market data for:  NEU 	Implied Vol:   0.00
# 649 | adding market data for:  SSNC 	Implied Vol:   0.39
# 648 | adding market data for:  SC 	Implied Vol:   0.44
# 647 | adding market data for:  IEX 	Implied Vol:   0.32
# 646 | adding market data for:  CME 	Implied Vol:   0.29
# 645 | adding market data for:  SPSC 	Implied Vol:   0.00
# 644 | adding market data for:  CPF 	Implied Vol:   0.00
# 643 | adding market data for:  NSC 	Implied Vol:   0.38
# 642 | adding market data for:  CHX 	Implied Vol:   0.81
# 641 | adding market data for:  EHC 	Implied Vol:   0.37
# 640 | adding market data for:  CMPR 	Implied Vol:   0.68
# 639 | adding market data for:  JOE 	Implied Vol:   0.41
# 638 | adding market data for:  MSC 	Implied Vol:   0.00
# 637 | adding market data for:  EQC 	Implied Vol:   0.00
# 636 | adding market data for:  GD 	Implied Vol:   0.32
# 635 | adding market data for:  TEL 	Implied Vol:   0.32
# 634 | adding market data for:  HCC 	Implied Vol:   0.70
# 633 | adding market data for:  HCC 	Implied Vol:   0.70
# 632 | adding market data for:  CMO 	Implied Vol:   0.44
# 631 | adding market data for:  CXO 	Implied Vol:   0.49
# 630 | adding market data for:  TMHC 	Implied Vol:   0.58
# 629 | adding market data for:  PPC 	Implied Vol:   0.46
# 628 | adding market data for:  RGR 	Implied Vol:   0.55
# 627 | adding market data for:  VSEC 	Implied Vol:   0.00
# 626 | adding market data for:  UTHR 	Implied Vol:   0.41
# 625 | adding market data for:  WIRE 	Implied Vol:   0.00
# 624 | adding market data for:  CREE 	Implied Vol:   0.71
# 623 | adding market data for:  GOOD 	Implied Vol:   0.33
# 622 | adding market data for:  CACI 	Implied Vol:   0.00
# 621 | adding market data for:  CNXN 	Implied Vol:   0.00
# 620 | adding market data for:  ELY 	Implied Vol:   0.66
# 619 | adding market data for:  FLIC 	Implied Vol:   0.00
# 618 | adding market data for:  CGNX 	Implied Vol:   0.52
# 617 | adding market data for:  CORR 	Implied Vol:   0.87
# 616 | adding market data for:  XAN 	Implied Vol:   0.72
# 615 | adding market data for:  TFSL 	Implied Vol:   0.31
# 614 | adding market data for:  KRNY 	Implied Vol:   0.36
# 613 | adding market data for:  DRE 	Implied Vol:   0.34
# 612 | adding market data for:  GRA 	Implied Vol:   0.49
# 611 | adding market data for:  DX 	Implied Vol:   0.30
# 610 | adding market data for:  CCS 	Implied Vol:   0.66
# 609 | adding market data for:  CCS 	Implied Vol:   0.66
# 608 | adding market data for:  NGVT 	Implied Vol:   0.47
# 607 | adding market data for:  CW 	Implied Vol:   0.00
# 606 | adding market data for:  OC 	Implied Vol:   0.42
# 605 | adding market data for:  HES 	Implied Vol:   0.61
# 604 | adding market data for:  KRA 	Implied Vol:   0.89
# 603 | adding market data for:  QMCO 	Implied Vol:   0.00
# 602 | adding market data for:  DGICA 	Implied Vol:   0.00
# 601 | adding market data for:  DORM 	Implied Vol:   0.42
# 600 | adding market data for:  MHH 	Implied Vol:   0.00
# 599 | adding market data for:  DAN 	Implied Vol:   0.59
# 598 | adding market data for:  DGICB 	Implied Vol:   0.00
# 597 | adding market data for:  DT 	Implied Vol:   0.62
# 596 | adding market data for:  DCO 	Implied Vol:   0.00
# 595 | adding market data for:  DBD 	Implied Vol:   0.89
# 594 | adding market data for:  FDP 	Implied Vol:   0.57
# 593 | adding market data for:  WYND 	Implied Vol:   0.59
# 592 | adding market data for:  GNMK 	Implied Vol:   1.03
# 591 | adding market data for:  EBAY 	Implied Vol:   0.59
# 590 | adding market data for:  ESS 	Implied Vol:   0.34
# 589 | adding market data for:  EPD 	Implied Vol:   0.32
# 588 | adding market data for:  ETSY 	Implied Vol:   1.01
# 587 | adding market data for:  ESRT 	Implied Vol:   0.53
# 586 | adding market data for:  NOVA 	Implied Vol:   1.04
# 585 | adding market data for:  ECHO 	Implied Vol:   0.51
# 584 | adding market data for:  WERN 	Implied Vol:   0.42
# 583 | adding market data for:  HEES 	Implied Vol:   0.60
# 582 | adding market data for:  EQIX 	Implied Vol:   0.32
# 581 | adding market data for:  EXTR 	Implied Vol:   0.81
# 580 | adding market data for:  WPX 	Implied Vol:   0.72
# 579 | adding market data for:  PE 	Implied Vol:   0.60
# 578 | adding market data for:  EEFT 	Implied Vol:   0.47
# 577 | adding market data for:  ENSG 	Implied Vol:   0.62
# 576 | adding market data for:  MLCO 	Implied Vol:   0.55
# 575 | adding market data for:  EPZM 	Implied Vol:   1.00
# 574 | adding market data for:  RJF 	Implied Vol:   0.36
# 573 | adding market data for:  FORM 	Implied Vol:   0.56
# 572 | adding market data for:  CASH 	Implied Vol:   0.00
# 571 | adding market data for:  CASH 	Implied Vol:   0.00
# 570 | adding market data for:  FLOW 	Implied Vol:   0.40
# 569 | adding market data for:  FARO 	Implied Vol:   0.00
# 568 | adding market data for:  FVRR 	Implied Vol:   0.92
# 567 | adding market data for:  FVRR 	Implied Vol:   0.92
# 566 | adding market data for:  SFM 	Implied Vol:   0.44
# 565 | adding market data for:  FRTA 	Implied Vol:   0.68
# 564 | adding market data for:  FSLY 	Implied Vol:   1.09
# 563 | adding market data for:  PROV 	Implied Vol:   0.00
# 562 | adding market data for:  SIGI 	Implied Vol:   0.35
# 561 | adding market data for:  JRVR 	Implied Vol:   0.00
# 560 | adding market data for:  KRG 	Implied Vol:   0.00
# 559 | adding market data for:  MRC 	Implied Vol:   0.00
# 558 | adding market data for:  WHG 	Implied Vol:   0.48
# 557 | adding market data for:  SAFT 	Implied Vol:   0.36
# 556 | adding market data for:  GMED 	Implied Vol:   0.43
# 555 | adding market data for:  MYRG 	Implied Vol:   0.52
# 554 | adding market data for:  GILD 	Implied Vol:   0.37
# 553 | adding market data for:  ORN 	Implied Vol:   0.00
# 552 | adding market data for:  SJW 	Implied Vol:   0.00
# 551 | adding market data for:  GRMN 	Implied Vol:   0.29
# 550 | adding market data for:  PGRE 	Implied Vol:   0.52
# 549 | adding market data for:  GNRC 	Implied Vol:   0.50
# 548 | adding market data for:  GLOP 	Implied Vol:   0.73
# 547 | adding market data for:  GRUB 	Implied Vol:   0.36
# 546 | adding market data for:  SPOK 	Implied Vol:   0.00
# 545 | adding market data for:  TDOC 	Implied Vol:   0.79
# 544 | adding market data for:  HOS 	Implied Vol:   0.00
# 543 | adding market data for:  WH 	Implied Vol:   0.47
# 542 | adding market data for:  INVH 	Implied Vol:   0.29
# 541 | adding market data for:  TROX 	Implied Vol:   0.68
# 540 | adding market data for:  INOV 	Implied Vol:   0.53
# 539 | adding market data for:  MHO 	Implied Vol:   0.61
# 538 | adding market data for:  HESM 	Implied Vol:   0.48
# 537 | adding market data for:  MOH 	Implied Vol:   0.52
# 536 | adding market data for:  VBTX 	Implied Vol:   0.00
# 535 | adding market data for:  LVGO 	Implied Vol:   0.72
# 534 | adding market data for:  ILPT 	Implied Vol:   0.34
# 533 | adding market data for:  OII 	Implied Vol:   0.94
# 532 | adding market data for:  TTMI 	Implied Vol:   0.48
# 531 | adding market data for:  MMSI 	Implied Vol:   0.00
# 530 | adding market data for:  MA 	Implied Vol:   0.35
# 529 | adding market data for:  IMMU 	Implied Vol:   0.28
# 528 | adding market data for:  TYL 	Implied Vol:   0.35
# 527 | adding market data for:  MNRO 	Implied Vol:   0.55
# 526 | adding market data for:  LBRT 	Implied Vol:   0.78
# 525 | adding market data for:  LDL 	Implied Vol:   0.00
# 524 | adding market data for:  MSA 	Implied Vol:   0.00
# 523 | adding market data for:  HZO 	Implied Vol:   0.70
# 522 | adding market data for:  KAI 	Implied Vol:   0.31
# 521 | adding market data for:  USLM 	Implied Vol:   0.00
# 520 | adding market data for:  ROL 	Implied Vol:   0.33
# 519 | adding market data for:  TW 	Implied Vol:   0.40
# 518 | adding market data for:  PEN 	Implied Vol:   0.70
# 517 | adding market data for:  V 	Implied Vol:   0.30
# 516 | adding market data for:  NOW 	Implied Vol:   0.52
# 515 | adding market data for:  MN 	Implied Vol:   0.68
# 514 | adding market data for:  RES 	Implied Vol:   0.96
# 513 | adding market data for:  INFI 	Implied Vol:   1.42
# 512 | adding market data for:  INVA 	Implied Vol:   0.57
# 511 | adding market data for:  PI 	Implied Vol:   0.74
# 510 | adding market data for:  MORN 	Implied Vol:   0.31
# 509 | adding market data for:  IRT 	Implied Vol:   0.40
# 508 | adding market data for:  PTC 	Implied Vol:   0.43
# 507 | adding market data for:  PPD 	Implied Vol:   0.51
# 506 | adding market data for:  MUSA 	Implied Vol:   0.00
# 505 | adding market data for:  EGOV 	Implied Vol:   0.36
# 504 | adding market data for:  SITE 	Implied Vol:   0.53
# 503 | adding market data for:  PINS 	Implied Vol:   1.46
# 502 | adding market data for:  QEP 	Implied Vol:   0.00
# 501 | adding market data for:  PKI 	Implied Vol:   0.37
# 500 | adding market data for:  URI 	Implied Vol:   0.55
# 499 | adding market data for:  VKTX 	Implied Vol:   0.78
# 498 | adding market data for:  ZVO 	Implied Vol:   1.47
# 497 | adding market data for:  WRI 	Implied Vol:   0.46
# 496 | adding market data for:  ORBC 	Implied Vol:   0.89
# 495 | adding market data for:  RYN 	Implied Vol:   0.32
# 494 | adding market data for:  VICI 	Implied Vol:   0.34
# 493 | adding market data for:  SLAB 	Implied Vol:   0.47
# 492 | adding market data for:  TXRH 	Implied Vol:   0.49
# 491 | adding market data for:  WELL 	Implied Vol:   0.45
# 490 | adding market data for:  SRI 	Implied Vol:   0.46
# 489 | adding market data for:  SREV 	Implied Vol:   0.00
# 488 | adding market data for:  PEGA 	Implied Vol:   0.46
# 487 | adding market data for:  VVV 	Implied Vol:   0.37
# 486 | adding market data for:  TESS 	Implied Vol:   0.00
# 485 | adding market data for:  TARO 	Implied Vol:   0.00
# 484 | adding market data for:  LFUS 	Implied Vol:   0.47
# 483 | adding market data for:  BPOP 	Implied Vol:   0.42
# 482 | adding market data for:  VTVT 	Implied Vol:   0.00
# 481 | adding market data for:  UPS 	Implied Vol:   0.59
# 480 | adding market data for:  QNST 	Implied Vol:   0.72
# 479 | adding market data for:  R 	Implied Vol:   0.45
# 478 | adding market data for:  VNDA 	Implied Vol:   0.75
# 477 | adding market data for:  PERI 	Implied Vol:   0.63
# 476 | adding market data for:  PERI 	Implied Vol:   0.63
# 475 | adding market data for:  YNDX 	Implied Vol:   0.49
# 474 | adding market data for:  VAL 	Implied Vol:   0.00
# 473 | adding market data for:  TT 	Implied Vol:   0.34
# 472 | adding market data for:  VALPQ 	Implied Vol:   0.00
# 471 | adding market data for:  FLWS 	Implied Vol:   0.75
# 470 | adding market data for:  GPI 	Implied Vol:   0.57
# 469 | adding market data for:  ASPN 	Implied Vol:   0.00
# 468 | adding market data for:  ASPN 	Implied Vol:   0.00
# 467 | adding market data for:  ADM 	Implied Vol:   0.31
# 466 | adding market data for:  ATVI 	Implied Vol:   0.51
# 465 | adding market data for:  GOOGL 	Implied Vol:   0.45
# 464 | adding market data for:  AAON 	Implied Vol:   0.40
# 463 | adding market data for:  AOS 	Implied Vol:   0.37
# 462 | adding market data for:  ARW 	Implied Vol:   0.35
# 461 | adding market data for:  AMZN 	Implied Vol:   0.59
# 460 | adding market data for:  ALKS 	Implied Vol:   0.71
# 459 | adding market data for:  CACC 	Implied Vol:   0.62
# 458 | adding market data for:  ALTA 	Implied Vol:   0.00
# 457 | adding market data for:  ATUS 	Implied Vol:   0.45
# 456 | adding market data for:  CBL 	Implied Vol:   0.00
# 455 | adding market data for:  APTV 	Implied Vol:   0.45
# 454 | adding market data for:  APO 	Implied Vol:   0.53
# 453 | adding market data for:  AME 	Implied Vol:   0.35
# 452 | adding market data for:  AX 	Implied Vol:   0.41
# 451 | adding market data for:  AMTB 	Implied Vol:   0.00
# 450 | adding market data for:  AMTB 	Implied Vol:   0.00
# 449 | adding market data for:  AINC 	Implied Vol:   0.00
# 448 | adding market data for:  ATI 	Implied Vol:   0.76
# 447 | adding market data for:  TEAM 	Implied Vol:   0.67
# 446 | adding market data for:  ABTX 	Implied Vol:   0.00
# 445 | adding market data for:  ABTX 	Implied Vol:   0.00
# 444 | adding market data for:  ADS 	Implied Vol:   0.81
# 443 | adding market data for:  AIV 	Implied Vol:   0.27
# 442 | adding market data for:  AAPL 	Implied Vol:   0.52
# 441 | adding market data for:  CENX 	Implied Vol:   0.81
# 440 | adding market data for:  FWRD 	Implied Vol:   0.00
# 439 | adding market data for:  MDRX 	Implied Vol:   0.59
# 438 | adding market data for:  ABMD 	Implied Vol:   0.54
# 437 | adding market data for:  WAB 	Implied Vol:   0.43
# 436 | adding market data for:  AMT 	Implied Vol:   0.31
# 435 | adding market data for:  FTAI 	Implied Vol:   0.43
# 434 | adding market data for:  ALRS 	Implied Vol:   0.00
# 433 | adding market data for:  ATR 	Implied Vol:   0.23
# 432 | adding market data for:  SAMG 	Implied Vol:   0.00
# 431 | adding market data for:  GOLF 	Implied Vol:   0.36
# 430 | adding market data for:  ETH 	Implied Vol:   0.61
# 429 | adding market data for:  CAR 	Implied Vol:   0.80
# 428 | adding market data for:  ATOM 	Implied Vol:   1.04
# 427 | adding market data for:  AJG 	Implied Vol:   0.24
# 426 | adding market data for:  ACRE 	Implied Vol:   0.48
# 425 | adding market data for:  AGEN 	Implied Vol:   1.05
# 424 | adding market data for:  ACGL 	Implied Vol:   0.37
# 423 | adding market data for:  HOME 	Implied Vol:   1.00
# 422 | adding market data for:  TDS 	Implied Vol:   0.59
# 421 | adding market data for:  AMTBB 	Implied Vol:   0.00
# 420 | adding market data for:  AMTBB 	Implied Vol:   0.00
# 419 | adding market data for:  AXGN 	Implied Vol:   0.63
# 418 | adding market data for:  AXGN 	Implied Vol:   0.63
# 417 | adding market data for:  SAH 	Implied Vol:   0.78
# 416 | adding market data for:  APRN 	Implied Vol:   1.18
# 415 | adding market data for:  APRN 	Implied Vol:   1.18
# 414 | adding market data for:  ARAY 	Implied Vol:   0.73
# 413 | adding market data for:  ACHC 	Implied Vol:   0.58
# 412 | adding market data for:  KTOS 	Implied Vol:   0.58
# 411 | adding market data for:  ALXN 	Implied Vol:   0.58
# 410 | adding market data for:  HBMD 	Implied Vol:   0.00
# 409 | adding market data for:  BAND 	Implied Vol:   0.66
# 408 | adding market data for:  DNKN 	Implied Vol:   0.38
# 407 | adding market data for:  BPMC 	Implied Vol:   0.52
# 406 | adding market data for:  HBP 	Implied Vol:   0.88
# 405 | adding market data for:  BC 	Implied Vol:   0.55
# 404 | adding market data for:  BLUE 	Implied Vol:   0.62
# 403 | adding market data for:  KTB 	Implied Vol:   0.63
# 402 | adding market data for:  BAX 	Implied Vol:   0.42
# 401 | adding market data for:  BCO 	Implied Vol:   0.61
# 400 | adding market data for:  GRBK 	Implied Vol:   0.55
# 399 | adding market data for:  EVLO 	Implied Vol:   0.00
# 398 | adding market data for:  EKSO 	Implied Vol:   0.00
# 397 | adding market data for:  BL 	Implied Vol:   0.62
# 396 | adding market data for:  BXC 	Implied Vol:   1.23
# 395 | adding market data for:  BSVN 	Implied Vol:   0.00
# 394 | adding market data for:  MRLN 	Implied Vol:   0.81
# 393 | adding market data for:  CNOB 	Implied Vol:   0.00
# 392 | adding market data for:  EVBN 	Implied Vol:   0.00
# 391 | adding market data for:  EVBN 	Implied Vol:   0.00
# 390 | adding market data for:  PCRX 	Implied Vol:   0.53
# 389 | adding market data for:  TSBK 	Implied Vol:   0.00
# 388 | adding market data for:  NTB 	Implied Vol:   0.00
# 387 | adding market data for:  BLDR 	Implied Vol:   0.54
# 386 | adding market data for:  CFR 	Implied Vol:   0.37
# 385 | adding market data for:  TBBK 	Implied Vol:   0.61
# 384 | adding market data for:  SBT 	Implied Vol:   0.00
# 383 | adding market data for:  PLX 	Implied Vol:   1.13
# 382 | adding market data for:  BEAT 	Implied Vol:   0.57
# 381 | adding market data for:  YUM 	Implied Vol:   0.36
# 380 | adding market data for:  BGS 	Implied Vol:   0.47
# 379 | adding market data for:  WTBA 	Implied Vol:   0.00
# 378 | adding market data for:  BE 	Implied Vol:   1.11
# 377 | adding market data for:  BE 	Implied Vol:   1.11
# 376 | adding market data for:  BSIG 	Implied Vol:   0.00
# 375 | adding market data for:  COLB 	Implied Vol:   0.53
# 374 | adding market data for:  BXMT 	Implied Vol:   0.37
# 373 | adding market data for:  TAP 	Implied Vol:   0.59
# 372 | adding market data for:  BWA 	Implied Vol:   0.41
# 371 | adding market data for:  BIO 	Implied Vol:   0.35
# 370 | adding market data for:  SBBP 	Implied Vol:   0.94
# 369 | adding market data for:  CMS 	Implied Vol:   0.22
# 368 | adding market data for:  LKQ 	Implied Vol:   0.42
# 367 | adding market data for:  CBRE 	Implied Vol:   0.39
# 366 | adding market data for:  WU 	Implied Vol:   0.38
# 365 | adding market data for:  CTO 	Implied Vol:   0.00
# 364 | adding market data for:  UVSP 	Implied Vol:   0.00
# 363 | adding market data for:  TRS 	Implied Vol:   0.00
# 362 | adding market data for:  CLDT 	Implied Vol:   0.65
# 361 | adding market data for:  PCGU 	Implied Vol:   0.00
# 360 | adding market data for:  EXAS 	Implied Vol:   0.67
# 359 | adding market data for:  SYK 	Implied Vol:   0.33
# 358 | adding market data for:  HUN 	Implied Vol:   0.41
# 357 | adding market data for:  ERIE 	Implied Vol:   0.39
# 356 | adding market data for:  SWN 	Implied Vol:   0.81
# 355 | adding market data for:  VC 	Implied Vol:   0.59
# 354 | adding market data for:  CPT 	Implied Vol:   0.00
# 353 | adding market data for:  CRL 	Implied Vol:   0.45
# 352 | adding market data for:  CBZ 	Implied Vol:   0.34
# 351 | adding market data for:  CMCO 	Implied Vol:   0.00
# 350 | adding market data for:  CTB 	Implied Vol:   0.58
# 349 | adding market data for:  TNC 	Implied Vol:   0.00
# 348 | adding market data for:  RYI 	Implied Vol:   0.00
# 347 | adding market data for:  RRC 	Implied Vol:   0.84
# 346 | adding market data for:  IPHI 	Implied Vol:   0.58
# 345 | adding market data for:  SGC 	Implied Vol:   0.90
# 344 | adding market data for:  QDEL 	Implied Vol:   0.86
# 343 | adding market data for:  SGC 	Implied Vol:   0.90
# 342 | adding market data for:  CURO 	Implied Vol:   0.81
# 341 | adding market data for:  RCL 	Implied Vol:   0.86
# 340 | adding market data for:  OCFC 	Implied Vol:   0.00
# 339 | adding market data for:  SO 	Implied Vol:   0.24
# 338 | adding market data for:  CHD 	Implied Vol:   0.30
# 337 | adding market data for:  CTT 	Implied Vol:   0.54
# 336 | adding market data for:  MMC 	Implied Vol:   0.26
# 335 | adding market data for:  NATI 	Implied Vol:   0.63
# 334 | adding market data for:  OLED 	Implied Vol:   0.80
# 333 | adding market data for:  CVNA 	Implied Vol:   1.03
# 332 | adding market data for:  GPOR 	Implied Vol:   0.00
# 331 | adding market data for:  MX 	Implied Vol:   0.67
# 330 | adding market data for:  X 	Implied Vol:   0.81
# 329 | adding market data for:  CATM 	Implied Vol:   0.83
# 328 | adding market data for:  OSK 	Implied Vol:   0.44
# 327 | adding market data for:  CWST 	Implied Vol:   0.35
# 326 | adding market data for:  CRAI 	Implied Vol:   0.65
# 325 | adding market data for:  COHU 	Implied Vol:   0.00
# 324 | adding market data for:  IMAX 	Implied Vol:   0.77
# 323 | adding market data for:  VVI 	Implied Vol:   0.00
# 322 | adding market data for:  VVI 	Implied Vol:   0.00
# 321 | adding market data for:  RLGY 	Implied Vol:   0.88
# 320 | adding market data for:  SM 	Implied Vol:   1.24
# 319 | adding market data for:  SM 	Implied Vol:   1.24
# 318 | adding market data for:  ROG 	Implied Vol:   0.00
# 317 | adding market data for:  PCG 	Implied Vol:   0.65
# 316 | adding market data for:  CRCQQ 	Implied Vol:   0.00
# 315 | adding market data for:  USM 	Implied Vol:   0.00
# 314 | adding market data for:  NEM 	Implied Vol:   0.38
# 313 | adding market data for:  KHC 	Implied Vol:   0.47
# 312 | adding market data for:  CMCSA 	Implied Vol:   0.32
# 311 | adding market data for:  FCN 	Implied Vol:   0.48
# 310 | adding market data for:  OFC 	Implied Vol:   0.00
# 309 | adding market data for:  KNSL 	Implied Vol:   0.45
# 308 | adding market data for:  KN 	Implied Vol:   0.48
# 307 | adding market data for:  CHX 	Implied Vol:   0.81
# 306 | adding market data for:  DVN 	Implied Vol:   0.76
# 305 | adding market data for:  DAIO 	Implied Vol:   0.00
# 304 | adding market data for:  DAIO 	Implied Vol:   0.00
# 303 | adding market data for:  SBUX 	Implied Vol:   0.37
# 302 | adding market data for:  IVC 	Implied Vol:   1.07
# 301 | adding market data for:  CDNA 	Implied Vol:   0.67
# 300 | adding market data for:  RM 	Implied Vol:   0.00
# 299 | adding market data for:  VCRA 	Implied Vol:   0.57
# 298 | adding market data for:  CDNA 	Implied Vol:   0.67
# 297 | adding market data for:  VCRA 	Implied Vol:   0.57
# 296 | adding market data for:  FDUS 	Implied Vol:   0.00
# 295 | adding market data for:  DECK 	Implied Vol:   0.50
# 294 | adding market data for:  SABR 	Implied Vol:   0.95
# 293 | adding market data for:  RL 	Implied Vol:   0.57
# 292 | adding market data for:  CXP 	Implied Vol:   0.38
# 291 | adding market data for:  ITGR 	Implied Vol:   0.54
# 290 | adding market data for:  USCR 	Implied Vol:   0.69
# 289 | adding market data for:  KEX 	Implied Vol:   0.52
# 288 | adding market data for:  CVA 	Implied Vol:   0.42
# 287 | adding market data for:  EMN 	Implied Vol:   0.38
# 286 | adding market data for:  CARR 	Implied Vol:   0.42
# 285 | adding market data for:  CARR 	Implied Vol:   0.42
# 284 | adding market data for:  COOP 	Implied Vol:   0.60
# 283 | adding market data for:  COOP 	Implied Vol:   0.60
# 282 | adding market data for:  MCO 	Implied Vol:   0.33
# 281 | adding market data for:  INT 	Implied Vol:   0.66
# 280 | adding market data for:  CNX 	Implied Vol:   0.67
# 279 | adding market data for:  FSS 	Implied Vol:   0.00
# 278 | adding market data for:  CERS 	Implied Vol:   0.51
# 277 | adding market data for:  CNST 	Implied Vol:   0.00
# 276 | adding market data for:  CERS 	Implied Vol:   0.51
# 275 | adding market data for:  CTS 	Implied Vol:   0.66
# 274 | adding market data for:  CTS 	Implied Vol:   0.66
# 273 | adding market data for:  ORC 	Implied Vol:   0.26
# 272 | adding market data for:  DWSN 	Implied Vol:   0.00
# 271 | adding market data for:  HTGC 	Implied Vol:   0.27
# 270 | adding market data for:  NEWM 	Implied Vol:   0.53
# 269 | adding market data for:  CG 	Implied Vol:   0.38
# 268 | adding market data for:  COG 	Implied Vol:   0.45
# 267 | adding market data for:  SPXC 	Implied Vol:   0.43
# 266 | adding market data for:  TKR 	Implied Vol:   0.38
# 265 | adding market data for:  CPLP 	Implied Vol:   0.43
# 264 | adding market data for:  COR 	Implied Vol:   0.00
# 263 | adding market data for:  CNSL 	Implied Vol:   0.69
# 262 | adding market data for:  K 	Implied Vol:   0.24
# 261 | adding market data for:  SEM 	Implied Vol:   0.54
# 260 | adding market data for:  CAKE 	Implied Vol:   0.65
# 259 | adding market data for:  CHE 	Implied Vol:   0.34
# 258 | adding market data for:  COP 	Implied Vol:   0.51
# 257 | adding market data for:  CDR 	Implied Vol:   1.65
# 256 | adding market data for:  CCC 	Implied Vol:   0.46
# 255 | adding market data for:  NVST 	Implied Vol:   0.55
# 254 | adding market data for:  IP 	Implied Vol:   0.37
# 253 | adding market data for:  CFX 	Implied Vol:   0.51
# 252 | adding market data for:  SSB 	Implied Vol:   0.42
# 251 | adding market data for:  UTL 	Implied Vol:   0.00
# 250 | adding market data for:  ULBI 	Implied Vol:   0.00
# 249 | adding market data for:  RBBN 	Implied Vol:   0.00
# 248 | adding market data for:  ULBI 	Implied Vol:   0.00
# 247 | adding market data for:  TMST 	Implied Vol:   0.00
# 246 | adding market data for:  COLM 	Implied Vol:   0.41
# 245 | adding market data for:  LADR 	Implied Vol:   0.47
# 244 | adding market data for:  KDP 	Implied Vol:   0.27
# 243 | adding market data for:  APPS 	Implied Vol:   1.13
# 242 | adding market data for:  DRQ 	Implied Vol:   0.60
# 241 | adding market data for:  DVA 	Implied Vol:   0.52
# 240 | adding market data for:  DVD 	Implied Vol:   0.00
# 239 | adding market data for:  DVD 	Implied Vol:   0.00
# 238 | adding market data for:  WD 	Implied Vol:   0.54
# 237 | adding market data for:  DLR 	Implied Vol:   0.30
# 236 | adding market data for:  FND 	Implied Vol:   0.59
# 235 | adding market data for:  DD 	Implied Vol:   0.41
# 234 | adding market data for:  ICE 	Implied Vol:   0.27
# 233 | adding market data for:  EVTC 	Implied Vol:   0.40
# 232 | adding market data for:  WWE 	Implied Vol:   0.56
# 231 | adding market data for:  RE 	Implied Vol:   0.32
# 230 | adding market data for:  EXP 	Implied Vol:   0.00
# 229 | adding market data for:  EME 	Implied Vol:   0.00
# 228 | adding market data for:  EIDX 	Implied Vol:   0.44
# 227 | adding market data for:  ERII 	Implied Vol:   0.50
# 226 | adding market data for:  LOCO 	Implied Vol:   0.67
# 225 | adding market data for:  PBF 	Implied Vol:   0.92
# 224 | adding market data for:  EXLS 	Implied Vol:   0.00
# 223 | adding market data for:  XEL 	Implied Vol:   0.23
# 222 | adding market data for:  EXPO 	Implied Vol:   0.00
# 221 | adding market data for:  WRE 	Implied Vol:   0.34
# 220 | adding market data for:  EIGI 	Implied Vol:   0.84
# 219 | adding market data for:  NFE 	Implied Vol:   0.77
# 218 | adding market data for:  LIND 	Implied Vol:   0.88
# 217 | adding market data for:  FIVN 	Implied Vol:   0.55
# 216 | adding market data for:  PFSI 	Implied Vol:   0.50
# 215 | adding market data for:  FB 	Implied Vol:   0.57
# 214 | adding market data for:  MOFG 	Implied Vol:   0.00
# 213 | adding market data for:  FORR 	Implied Vol:   0.00
# 212 | adding market data for:  FHI 	Implied Vol:   0.00
# 211 | adding market data for:  HIG 	Implied Vol:   0.43
# 210 | adding market data for:  FTNT 	Implied Vol:   0.46
# 209 | adding market data for:  FII 	Implied Vol:   0.17
# 208 | adding market data for:  FIS 	Implied Vol:   0.30
# 207 | adding market data for:  SBFG 	Implied Vol:   0.00
# 206 | adding market data for:  FISI 	Implied Vol:   0.00
# 205 | adding market data for:  LPLA 	Implied Vol:   0.00
# 204 | adding market data for:  FLEX 	Implied Vol:   0.69
# 203 | adding market data for:  JRVR 	Implied Vol:   0.00
# 202 | adding market data for:  HGV 	Implied Vol:   0.53
# 201 | adding market data for:  GIGM 	Implied Vol:   0.00
# 200 | adding market data for:  GPN 	Implied Vol:   0.39
# 199 | adding market data for:  ROCK 	Implied Vol:   0.48
# 198 | adding market data for:  LEAF 	Implied Vol:   1.08
# 197 | adding market data for:  TROW 	Implied Vol:   0.30
# 196 | adding market data for:  ORN 	Implied Vol:   0.00
# 195 | adding market data for:  GSHD 	Implied Vol:   0.00
# 194 | adding market data for:  GEO 	Implied Vol:   0.86
# 193 | adding market data for:  THRM 	Implied Vol:   0.46
# 192 | adding market data for:  PENN 	Implied Vol:   0.98
# 191 | adding market data for:  JHG 	Implied Vol:   0.54
# 190 | adding market data for:  HUBG 	Implied Vol:   0.00
# 189 | adding market data for:  TGH 	Implied Vol:   0.75
# 188 | adding market data for:  GSIT 	Implied Vol:   0.00
# 187 | adding market data for:  SYNH 	Implied Vol:   0.48
# 186 | adding market data for:  SLCA 	Implied Vol:   1.03
# 185 | adding market data for:  PRO 	Implied Vol:   0.65
# 184 | adding market data for:  TRWH 	Implied Vol:   0.62
# 183 | adding market data for:  TRWH 	Implied Vol:   0.62
# 182 | adding market data for:  HLI 	Implied Vol:   0.00
# 181 | adding market data for:  TROX 	Implied Vol:   0.68
# 180 | adding market data for:  MDC 	Implied Vol:   0.48
# 179 | adding market data for:  PEB 	Implied Vol:   0.69
# 178 | adding market data for:  XTNT 	Implied Vol:   0.00
# 177 | adding market data for:  XTNT 	Implied Vol:   0.00
# 176 | adding market data for:  OPK 	Implied Vol:   1.73
# 175 | adding market data for:  MGLN 	Implied Vol:   0.36
# 174 | adding market data for:  HPP 	Implied Vol:   0.44
# 173 | adding market data for:  OHI 	Implied Vol:   0.39
# 172 | adding market data for:  ULH 	Implied Vol:   0.00
# 171 | adding market data for:  MOBL 	Implied Vol:   0.08
# 170 | adding market data for:  NNN 	Implied Vol:   0.41
# 169 | adding market data for:  MTX 	Implied Vol:   0.00
# 168 | adding market data for:  ILMN 	Implied Vol:   0.48
# 167 | adding market data for:  YRCW 	Implied Vol:   1.22
# 166 | adding market data for:  NTUS 	Implied Vol:   0.67
# 165 | adding market data for:  SHAK 	Implied Vol:   0.81
# 164 | adding market data for:  SAIA 	Implied Vol:   0.00
# 163 | adding market data for:  TPX 	Implied Vol:   0.58
# 162 | adding market data for:  MGPI 	Implied Vol:   0.59
# 161 | adding market data for:  MGPI 	Implied Vol:   0.59
# 160 | adding market data for:  PATK 	Implied Vol:   0.61
# 159 | adding market data for:  PATK 	Implied Vol:   0.61
# 158 | adding market data for:  OSTK 	Implied Vol:   1.46
# 157 | adding market data for:  INSM 	Implied Vol:   0.60
# 156 | adding market data for:  PRTO 	Implied Vol:   0.00
# 155 | adding market data for:  SUNW 	Implied Vol:   0.00
# 154 | adding market data for:  TXT 	Implied Vol:   0.49
# 153 | adding market data for:  LAWS 	Implied Vol:   0.00
# 152 | adding market data for:  LAWS 	Implied Vol:   0.00
# 151 | adding market data for:  PRLB 	Implied Vol:   0.52
# 150 | adding market data for:  LMAT 	Implied Vol:   0.00
# 149 | adding market data for:  LMAT 	Implied Vol:   0.00
# 148 | adding market data for:  ZEN 	Implied Vol:   0.52
# 147 | adding market data for:  MLM 	Implied Vol:   0.39
# 146 | adding market data for:  PLT 	Implied Vol:   1.01
# 145 | adding market data for:  POWI 	Implied Vol:   0.39
# 144 | adding market data for:  PDM 	Implied Vol:   0.42
# 143 | adding market data for:  MRNA 	Implied Vol:   0.91
# 142 | adding market data for:  PTCT 	Implied Vol:   0.00
# 141 | adding market data for:  TPR 	Implied Vol:   0.74
# 140 | adding market data for:  OIS 	Implied Vol:   1.02
# 139 | adding market data for:  TFX 	Implied Vol:   0.33
# 138 | adding market data for:  WEX 	Implied Vol:   0.49
# 137 | adding market data for:  KBR 	Implied Vol:   0.42
# 136 | adding market data for:  MYE 	Implied Vol:   0.00
# 135 | adding market data for:  MYE 	Implied Vol:   0.00
# 134 | adding market data for:  LYTS 	Implied Vol:   0.00
# 133 | adding market data for:  MGM 	Implied Vol:   0.75
# 132 | adding market data for:  PXLW 	Implied Vol:   1.25
# 131 | adding market data for:  PXLW 	Implied Vol:   1.25
# 130 | adding market data for:  SNDR 	Implied Vol:   0.35
# 129 | adding market data for:  SKYW 	Implied Vol:   0.79
# 128 | adding market data for:  PMT 	Implied Vol:   0.37
# 127 | adding market data for:  PRFT 	Implied Vol:   0.41
# 126 | adding market data for:  PSMT 	Implied Vol:   0.44
# 125 | adding market data for:  PDFS 	Implied Vol:   0.54
# 124 | adding market data for:  UDR 	Implied Vol:   0.38
# 123 | adding market data for:  TWTR 	Implied Vol:   0.85
# 122 | adding market data for:  MPWR 	Implied Vol:   0.45
# 121 | adding market data for:  RWT 	Implied Vol:   0.48
# 120 | adding market data for:  IDXX 	Implied Vol:   0.39
# 119 | adding market data for:  NBR 	Implied Vol:   1.28
# 118 | adding market data for:  USAK 	Implied Vol:   0.83
# 117 | adding market data for:  TRUP 	Implied Vol:   0.75
# 116 | adding market data for:  NTCT 	Implied Vol:   0.00
# 115 | adding market data for:  SHOP 	Implied Vol:   0.68
# 114 | adding market data for:  PWR 	Implied Vol:   0.43
# 113 | adding market data for:  MDCA 	Implied Vol:   1.43
# 112 | adding market data for:  VRTX 	Implied Vol:   0.42
# 111 | adding market data for:  NUVA 	Implied Vol:   0.71
# 110 | adding market data for:  MERC 	Implied Vol:   0.52
# 109 | adding market data for:  SOI 	Implied Vol:   0.63
# 108 | adding market data for:  TARA 	Implied Vol:   0.00
# 107 | adding market data for:  RMD 	Implied Vol:   0.41
# 106 | adding market data for:  PFPT 	Implied Vol:   0.49
# 105 | adding market data for:  LTC 	Implied Vol:   0.43
# 104 | adding market data for:  IDA 	Implied Vol:   0.33
# 103 | adding market data for:  LPSN 	Implied Vol:   0.71
# 102 | adding market data for:  MHK 	Implied Vol:   0.60
# 101 | adding market data for:  SKX 	Implied Vol:   0.83
# 100 | adding market data for:  XYL 	Implied Vol:   0.34
# 99 | adding market data for:  WW 	Implied Vol:   1.02
# 98 | adding market data for:  MSI 	Implied Vol:   0.35
# 97 | adding market data for:  MTZ 	Implied Vol:   0.50
# 96 | adding market data for:  OSIS 	Implied Vol:   0.39
# 95 | adding market data for:  MPW 	Implied Vol:   0.30
# 94 | adding market data for:  MVIS 	Implied Vol:   1.69
# 93 | adding market data for:  MVIS 	Implied Vol:   1.69
# 92 | adding market data for:  LAZ 	Implied Vol:   0.42
# 91 | adding market data for:  NMM 	Implied Vol:   0.89
# 90 | adding market data for:  PBFX 	Implied Vol:   0.54
# 89 | adding market data for:  STNE 	Implied Vol:   0.77
# 88 | adding market data for:  STNE 	Implied Vol:   0.77
# 87 | adding market data for:  LIVN 	Implied Vol:   0.00
# 86 | adding market data for:  SILC 	Implied Vol:   0.00
# 85 | adding market data for:  TPL 	Implied Vol:   0.00
# 84 | adding market data for:  NVCR 	Implied Vol:   0.61
# 83 | adding market data for:  MGRC 	Implied Vol:   0.00
# 82 | adding market data for:  WLTW 	Implied Vol:   0.31
# 81 | adding market data for:  SPOT 	Implied Vol:   0.71
# 80 | adding market data for:  PSX 	Implied Vol:   0.49
# 79 | adding market data for:  PSXP 	Implied Vol:   0.41
# 78 | adding market data for:  BAH 	Implied Vol:   0.31
# 77 | adding market data for:  ABBV 	Implied Vol:   0.33
# 76 | adding market data for:  UAA 	Implied Vol:   0.88
# 75 | adding market data for:  MO 	Implied Vol:   0.33
# 74 | adding market data for:  AMAG 	Implied Vol:   0.09
# 73 | adding market data for:  ATRO 	Implied Vol:   0.00
# 72 | adding market data for:  ATRO 	Implied Vol:   0.00
# 71 | adding market data for:  ABR 	Implied Vol:   0.33
# 70 | adding market data for:  ASIX 	Implied Vol:   0.00
# 69 | adding market data for:  ASIX 	Implied Vol:   0.00
# 68 | adding market data for:  AXL 	Implied Vol:   0.81
# 67 | adding market data for:  ATRI 	Implied Vol:   0.00
# 66 | adding market data for:  AON 	Implied Vol:   0.29
# 65 | adding market data for:  BR 	Implied Vol:   0.26
# 64 | adding market data for:  ROLL 	Implied Vol:   0.00
# 63 | adding market data for:  IBP 	Implied Vol:   0.62
# 62 | adding market data for:  GRBK 	Implied Vol:   0.55
# 61 | adding market data for:  PBI 	Implied Vol:   0.87
# 60 | adding market data for:  BGGSQ 	Implied Vol:   0.00
# 59 | adding market data for:  BH 	Implied Vol:   0.00
# 58 | adding market data for:  NWL 	Implied Vol:   0.45
# 57 | adding market data for:  BCC 	Implied Vol:   0.00
# 56 | adding market data for:  BELFB 	Implied Vol:   0.00
# 55 | adding market data for:  FBP 	Implied Vol:   0.48
# 54 | adding market data for:  LBRDA 	Implied Vol:   0.00
# 53 | adding market data for:  BGG 	Implied Vol:   0.00
# 52 | adding market data for:  BELFA 	Implied Vol:   0.00
# 51 | adding market data for:  CURO 	Implied Vol:   0.81
# 50 | adding market data for:  PIPR 	Implied Vol:   0.00
# 49 | adding market data for:  CHTR 	Implied Vol:   0.35
# 48 | adding market data for:  LEA 	Implied Vol:   0.43
# 47 | adding market data for:  XOM 	Implied Vol:   0.42
# 46 | adding market data for:  CTT 	Implied Vol:   0.54
# 45 | adding market data for:  CSWC 	Implied Vol:   0.32
# 44 | adding market data for:  CL 	Implied Vol:   0.29
# 43 | adding market data for:  POR 	Implied Vol:   0.34
# 42 | adding market data for:  PNW 	Implied Vol:   0.23
# 41 | adding market data for:  WY 	Implied Vol:   0.47
# 40 | adding market data for:  KKR 	Implied Vol:   0.36
# 39 | adding market data for:  IRMD 	Implied Vol:   0.00
# 38 | adding market data for:  CBOE 	Implied Vol:   0.32
# 37 | adding market data for:  IRMD 	Implied Vol:   0.00
# 36 | adding market data for:  ORC 	Implied Vol:   0.26
# 35 | adding market data for:  IPGP 	Implied Vol:   0.50
# 34 | adding market data for:  MSEX 	Implied Vol:   0.00
# 33 | adding market data for:  CVX 	Implied Vol:   0.40
# 32 | adding market data for:  WPC 	Implied Vol:   0.31
# 31 | adding market data for:  SCM 	Implied Vol:   0.00
# 30 | adding market data for:  TWIN 	Implied Vol:   0.71
# 29 | adding market data for:  DSKE 	Implied Vol:   1.27
# 28 | adding market data for:  DSKE 	Implied Vol:   1.27
# 27 | adding market data for:  PEG 	Implied Vol:   0.26
# 26 | adding market data for:  NVT 	Implied Vol:   0.43
# 25 | adding market data for:  NVT 	Implied Vol:   0.43
# 24 | adding market data for:  FLIR 	Implied Vol:   0.54
# 23 | adding market data for:  PFS 	Implied Vol:   0.00
# 22 | adding market data for:  SBFG 	Implied Vol:   0.00
# 21 | adding market data for:  PQG 	Implied Vol:   0.49
# 20 | adding market data for:  SNR 	Implied Vol:   0.65
# 19 | adding market data for:  RUTH 	Implied Vol:   0.78
# 18 | adding market data for:  XHR 	Implied Vol:   0.70
# 17 | adding market data for:  ULH 	Implied Vol:   0.00
# 16 | adding market data for:  HON 	Implied Vol:   0.33
# 15 | adding market data for:  OPINI 	Implied Vol:   0.00
# 14 | adding market data for:  LHX 	Implied Vol:   0.33
# 13 | adding market data for:  ITT 	Implied Vol:   0.38
# 12 | adding market data for:  WETF 	Implied Vol:   0.58
# 11 | adding market data for:  LYB 	Implied Vol:   0.47
# 10 | adding market data for:  LGND 	Implied Vol:   0.82
# 9 | adding market data for:  USAK 	Implied Vol:   0.83
# 8 | adding market data for:  PNM 	Implied Vol:   0.04
# 7 | adding market data for:  SOI 	Implied Vol:   0.63
# 6 | adding market data for:  OPI 	Implied Vol:   0.42
# 5 | adding market data for:  OIIM 	Implied Vol:   0.00
# 4 | adding market data for:  OIIM 	Implied Vol:   0.00
# 3 | adding market data for:  MGI 	Implied Vol:   1.22
# 2 | adding market data for:  MGI 	Implied Vol:   1.22
# 1 | adding market data for:  MMP 	Implied Vol:   0.31
# 0 | adding market data for:  SHLX 	Implied Vol:   0.67
#
# Completed - setup.addMarketData....

# %%
buildCsvSummary.saveCsvSummary(yahooEarningsOfInterestDF, allYahooEarningsForWeekDF, startday)

endTime = datetime.datetime.now()

print('End Time: ', endTime.strftime("%Y-%m-%d %H:%M"))
print('Elapsed Time: ', endTime - startTime, '\nDone' )
# Out:
# End Time:  2020-10-24 12:44
# Elapsed Time:  0:13:05.023843
# Done
