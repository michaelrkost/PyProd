# %%
#Get the iWidget stuff
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import os
import sys
from pathlib import Path 
sys.path.append('/home/michael/jupyter/local-packages')
import numpy as np
import pandas as pd
import datetime
from datetime import timedelta
import random
import itertools

# Get my Utilities (localUtilities)earningWeekDir / 
from localUtilities import dateUtils, errorHandler
# from localUtilities.webScrape import earningYahoo
from localUtilities.ibUtils import getOptionStrategyPrice as strat
from localUtilities.ibUtils import setup as setup

from localUtilities.webScrape import getEarningsOnDate
from localUtilities.ibUtils import buildCsvSummary 

# Doc is here: https://ib-insync.readthedocs.io/readme.html
from ib_insync import *
util.startLoop()

ib = IB()

# Connect to IB Gateway / Paper Trade 4002 
#            TWS        / Paper Trade 7495
ib.connect('127.0.0.1', 4002, clientId=7)

# ib.setCallback('error', errorHandler.onError)
# Out:
# <IB connected to 127.0.0.1:4002 clientId=7>

# %%
# Starting day of the earnings week.
startday = '2019-10-07'

# %%
# get earnings from Yahoo for the week of startdate
anEarningsDF = getEarningsOnDate.getEarningsForWeek(startday)
# Out:
# 1-18 of 18 results
# Working Day:  2019-10-07
# 1-9 of 9 results
# Working Day:  2019-10-08
# 1-4 of 4 results
# Working Day:  2019-10-09
# 1-10 of 10 results
# Working Day:  2019-10-10
# 1-16 of 16 results
# Working Day:  2019-10-11

# %%
# Add Market Data: 
#    Close Price, Last Price, Historic Volatility, Implied Volatility, Option Volume, Expected Range $ move
earningsDF, earningsDFAll = setup.addMarketData(ib, anEarningsDF, startday)
# Out:
# AGHC, ARTW, PTPF, GNBT, UBCP, SPRS, TAQR, FGP, GTHP, FCRE, GWPH, PHIL, GRIF, USATP, RWWI, INSYQ, NPK, MGPC, AZZ, BORT, LEVI, STCC, DPZ, EROS, FREDQ, GRBX, HELE, CBSH, SAR, EMMS, III, DAL, FBSI,
# Error 200, reqId 69: No security definition has been found for the request, contract: Stock(symbol='IIBK', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='IIBK', exchange='SMART', currency='USD')
# Error 200, reqId 70: No security definition has been found for the request, contract: Stock(symbol='IIBK', exchange='SMART', currency='USD')
# IIBK,
# Error 300, reqId 70: Can't find EId with tickerId:70
# SAR, IDT, RELL, MHGU, TR, PTSI, NNVC, ADTR, ODC, HMNY, BEBE, BLIBQ, XBOR, VOXX,
# Error 200, reqId 99: No security definition has been found for the request, contract: Stock(symbol='HYCT', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='HYCT', exchange='SMART', currency='USD')
# Error 200, reqId 100: No security definition has been found for the request, contract: Stock(symbol='HYCT', exchange='SMART', currency='USD')
# HYCT,
# Error 300, reqId 100: Can't find EId with tickerId:100
# TCEC, FAST,
# Error 200, reqId 105: No security definition has been found for the request, contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# Error 200, reqId 106: No security definition has been found for the request, contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# DHCPW,
# Error 300, reqId 106: Can't find EId with tickerId:106
# Error 200, reqId 107: No security definition has been found for the request, contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# Error 200, reqId 108: No security definition has been found for the request, contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# DHCPW,
# Error 300, reqId 108: Can't find EId with tickerId:108
# TTEN, FLXI, PENC, WFTIQ, AGHC  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  AGHC
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# ARTW  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  ARTW
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# PTPF  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  PTPF
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# GNBT  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  GNBT
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# UBCP  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  UBCP
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# SPRS  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  SPRS
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# TAQR  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  TAQR
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# FGP  -   57, not returing empty
# putsOpenInterest:  12 callsOpenInterest:  9
# GTHP  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  GTHP
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# FCRE  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  FCRE
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# GWPH  -   57, not returing empty
# putsOpenInterest:  16555 callsOpenInterest:  6350
# PHIL  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  PHIL
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# GRIF  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  GRIF
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# USATP  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  USATP
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# RWWI  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  RWWI
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# INSYQ  -   57, not returing empty
# putsOpenInterest:  0 callsOpenInterest:  0
# NPK  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  NPK
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# MGPC  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  MGPC
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# AZZ  -   57, not returing empty
# putsOpenInterest:  396 callsOpenInterest:  206
# BORT  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  BORT
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# LEVI  -   57, not returing empty
# putsOpenInterest:  10431 callsOpenInterest:  11971
# STCC  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  STCC
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# DPZ  -   57, not returing empty
# putsOpenInterest:  2382 callsOpenInterest:  4161
# EROS  -   57, not returing empty
# putsOpenInterest:  15915 callsOpenInterest:  1615
# FREDQ  -   57, not returing empty
# putsOpenInterest:  414 callsOpenInterest:  64
# GRBX  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  GRBX
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# HELE  -   57, not returing empty
# putsOpenInterest:  750 callsOpenInterest:  1077
# CBSH  -   57, not returing empty
# putsOpenInterest:  109 callsOpenInterest:  13
# SAR  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  SAR
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# EMMS  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  EMMS
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# III  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  III
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# DAL  -   57, not returing empty
# putsOpenInterest:  14845 callsOpenInterest:  9637
# FBSI  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  FBSI
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# Error 200, reqId 183: No security definition has been found for the request, contract: Stock(symbol='IIBK', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='IIBK', exchange='SMART', currency='USD')
# Error 200, reqId 184: No security definition has been found for the request, contract: Stock(symbol='IIBK', exchange='SMART', currency='USD')
# IIBK  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  IIBK
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# Error 300, reqId 184: Can't find EId with tickerId:184
# SAR  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  SAR
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# IDT  -   57, not returing empty
# putsOpenInterest:  254 callsOpenInterest:  67
# RELL  -   57, not returing empty
# putsOpenInterest:  20 callsOpenInterest:  0
# MHGU  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  MHGU
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# TR  -   57, not returing empty
# putsOpenInterest:  74 callsOpenInterest:  147
# PTSI  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  PTSI
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# NNVC  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  NNVC
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# ADTR  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  ADTR
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# ODC  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  ODC
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# HMNY  -   57, not returing empty
# putsOpenInterest:  0 callsOpenInterest:  0
# BEBE  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  BEBE
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# BLIBQ  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  BLIBQ
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# XBOR  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  XBOR
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# VOXX  -   57, not returing empty
# putsOpenInterest:  406 callsOpenInterest:  16
# Error 200, reqId 213: No security definition has been found for the request, contract: Stock(symbol='HYCT', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='HYCT', exchange='SMART', currency='USD')
# Error 200, reqId 214: No security definition has been found for the request, contract: Stock(symbol='HYCT', exchange='SMART', currency='USD')
# HYCT  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  HYCT
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# Error 300, reqId 214: Can't find EId with tickerId:214
# TCEC  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  TCEC
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# FAST  -   57, not returing empty
# putsOpenInterest:  2600 callsOpenInterest:  6836
# Error 200, reqId 219: No security definition has been found for the request, contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# Error 200, reqId 220: No security definition has been found for the request, contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# DHCPW  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  DHCPW
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# Error 300, reqId 220: Can't find EId with tickerId:220
# Error 200, reqId 221: No security definition has been found for the request, contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# Error 200, reqId 222: No security definition has been found for the request, contract: Stock(symbol='DHCPW', exchange='SMART', currency='USD')
# DHCPW  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  DHCPW
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# Error 300, reqId 222: Can't find EId with tickerId:222
# TTEN  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  TTEN
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# FLXI  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  FLXI
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# PENC  -   57,       <class 'ValueError'> In getOptionInfo.getOccVolume
#               Symbol:  PENC
#               df.empty:  True
# returning Empty
# putsOpenInterest:  0 callsOpenInterest:  0
# WFTIQ  -   57, not returing empty
# putsOpenInterest:  0 callsOpenInterest:  0

# %%
# check out the data
earningsDF
# Out:
#   Symbol Earnings_Date                 Company  Earnings Call Time   close  \
# 0   GWPH    2019-10-07  GW Pharmaceuticals PLC   Time Not Supplied  119.90
# 1   LEVI    2019-10-08       Levi Strauss & Co                 TAS   18.72
# 2    DPZ    2019-10-08      Domino's Pizza Inc                 TAS  243.00
# 3   EROS    2019-10-08  Eros International PLC  Before Market Open    1.69
# 4   HELE    2019-10-08       Helen of Troy Ltd  Before Market Open  160.00
# 5    DAL    2019-10-10     Delta Air Lines Inc  Before Market Open   53.90
# 6   FAST    2019-10-11             Fastenal Co  Before Market Open   31.68
#
#      last  histVolatility  impliedVolatility  PutFridayOpenInterest  \
# 0  113.75             NaN                NaN                16555.0
# 1   19.45             NaN                NaN                10431.0
# 2  243.35             NaN                NaN                 2382.0
# 3    1.70        1.552727           1.901452                15915.0
# 4  159.11             NaN                NaN                  750.0
# 5   52.83             NaN                NaN                14845.0
# 6   31.01             NaN                NaN                 2600.0
#
#    CallFridayOpenInterest  Expected_Range
# 0                  6350.0             NaN
# 1                 11971.0             NaN
# 2                  4161.0             NaN
# 3                  1615.0            0.61
# 4                  1077.0             NaN
# 5                  9637.0             NaN
# 6                  6836.0             NaN

# %%
earningsDFAll
# Out:
#    Symbol Earnings_Date                            Company  \
# 0    AGHC    2019-10-07            Aeon Global Health Corp
# 1    ARTW    2019-10-07     Art's Way Manufacturing Co Inc
# 2    PTPF    2019-10-07        All Marketing Solutions Inc
# 3    GNBT    2019-10-07         Generex Biotechnology Corp
# 4    UBCP    2019-10-07                 United Bancorp Inc
# 5    SPRS    2019-10-07               Surge Components Inc
# 6    TAQR    2019-10-07                        Traqer Corp
# 7     FGP    2019-10-07             Ferrellgas Partners LP
# 8    GTHP    2019-10-07            Guided Therapeutics Inc
# 9    FCRE    2019-10-07             Gadsden Properties Inc
# 10   GWPH    2019-10-07             GW Pharmaceuticals PLC
# 11   PHIL    2019-10-07                      PHI Group Inc
# 12   GRIF    2019-10-07      Griffin Industrial Realty Inc
# 13  USATP    2019-10-07               USA Technologies Inc
# 14   RWWI    2019-10-07                 Rand Worldwide Inc
# 15  INSYQ    2019-10-07             INSYS Therapeutics Inc
# 16    NPK    2019-10-07     National Presto Industries Inc
# 17   MGPC    2019-10-07              Moregain Pictures Inc
# 18    AZZ    2019-10-08                            AZZ Inc
# 19   BORT    2019-10-08           Botetourt Bankshares Inc
# 20   LEVI    2019-10-08                  Levi Strauss & Co
# 21   STCC    2019-10-08         Sterling Consolidated Corp
# 22    DPZ    2019-10-08                 Domino's Pizza Inc
# 23   EROS    2019-10-08             Eros International PLC
# 24  FREDQ    2019-10-08                         Fred's Inc
# 25   GRBX    2019-10-08                       Greenbox Pos
# 26   HELE    2019-10-08                  Helen of Troy Ltd
# 27   CBSH    2019-10-09            Commerce Bancshares Inc
# 28    SAR    2019-10-09           Saratoga Investment Corp
# 29   EMMS    2019-10-09          Emmis Communications Corp
# 30    III    2019-10-09     Information Services Group Inc
# 31    DAL    2019-10-10                Delta Air Lines Inc
# 32   FBSI    2019-10-10    First Bancshares Inc (Missouri)
# 33   IIBK    2019-10-10             Idaho Independent Bank
# 34    SAR    2019-10-10           Saratoga Investment Corp
# 35    IDT    2019-10-10                           IDT Corp
# 36   RELL    2019-10-10         Richardson Electronics Ltd
# 37   MHGU    2019-10-10     Meritage Hospitality Group Inc
# 38     TR    2019-10-10        Tootsie Roll Industries Inc
# 39   PTSI    2019-10-10    PAM Transportation Services Inc
# 40   NNVC    2019-10-10                  NanoViricides Inc
# 41   ADTR    2019-10-11        Alliance Media Holdings Inc
# 42    ODC    2019-10-11     Oil-Dri Corporation of America
# 43   HMNY    2019-10-11  Helios and Matheson Analytics Inc
# 44   BEBE    2019-10-11                    bebe stores inc
# 45  BLIBQ    2019-10-11                 BB Liquidating Inc
# 46   XBOR    2019-10-11         Cross Border Resources Inc
# 47   VOXX    2019-10-11            VOXX International Corp
# 48   HYCT    2019-10-11                Hycroft Mining Corp
# 49   TCEC    2019-10-11                  TransCoastal Corp
# 50   FAST    2019-10-11                        Fastenal Co
# 51  DHCPW    2019-10-11                Ditech Holding Corp
# 52  DHCPW    2019-10-11                Ditech Holding Corp
# 53   TTEN    2019-10-11                   Titan Energy LLC
# 54   FLXI    2019-10-11    Flexiinternational Software Inc
# 55   PENC    2019-10-11                            Pen Inc
# 56  WFTIQ    2019-10-11      Weatherford International PLC
#
#     Earnings Call Time     close      last  histVolatility  impliedVolatility  \
# 0    Time Not Supplied    0.1050    0.1080             NaN                NaN
# 1   Before Market Open    2.0700    2.1200             NaN                NaN
# 2    Time Not Supplied       NaN    0.0072             NaN                NaN
# 3    Time Not Supplied    2.0900    2.0000             NaN                NaN
# 4   Before Market Open   10.9700   11.0600             NaN                NaN
# 5   After Market Close    3.2500    3.2500             NaN                NaN
# 6    Time Not Supplied       NaN    1.8000             NaN                NaN
# 7                  TAS    0.9010    0.9500             NaN                NaN
# 8    Time Not Supplied    0.1800    0.2097             NaN                NaN
# 9    Time Not Supplied       NaN    0.1499             NaN                NaN
# 10   Time Not Supplied  119.9000  113.7500             NaN                NaN
# 11   Time Not Supplied    0.0001    0.0001             NaN                NaN
# 12   Time Not Supplied   36.3200   35.9500             NaN                NaN
# 13  Before Market Open       NaN   22.0000             NaN                NaN
# 14   Time Not Supplied    7.3500    7.2500             NaN                NaN
# 15  After Market Close    0.1200    0.1330             NaN                NaN
# 16  After Market Close   85.3000   85.3800             NaN                NaN
# 17   Time Not Supplied       NaN    0.0800             NaN                NaN
# 18  Before Market Open   42.8000   42.3300             NaN                NaN
# 19  Before Market Open       NaN   28.5500             NaN                NaN
# 20                 TAS   18.7200   19.4500             NaN                NaN
# 21   Time Not Supplied    0.0430    0.0633             NaN                NaN
# 22                 TAS  243.0000  243.3500             NaN                NaN
# 23  Before Market Open    1.6900    1.7000        1.552727           1.901452
# 24  Before Market Open    0.0445    0.0540             NaN                NaN
# 25   Time Not Supplied    0.1324    0.1300             NaN                NaN
# 26  Before Market Open  160.0000  159.1100             NaN                NaN
# 27                 TAS   59.0000   58.4700             NaN                NaN
# 28  After Market Close   24.1100   24.0000             NaN                NaN
# 29  Before Market Open       NaN    5.0100             NaN                NaN
# 30                 TAS    2.5100    2.5100             NaN                NaN
# 31  Before Market Open   53.9000   52.8300             NaN                NaN
# 32   Time Not Supplied       NaN   14.8000             NaN                NaN
# 33   Time Not Supplied       NaN       NaN             NaN                NaN
# 34                 TAS   24.1100   24.0000        0.105553                NaN
# 35                 TAS    9.0700   10.2100             NaN                NaN
# 36                 TAS    5.6500    5.6900             NaN                NaN
# 37   Time Not Supplied       NaN   16.7300             NaN                NaN
# 38  After Market Close   36.7500   36.4700             NaN                NaN
# 39  Before Market Open   61.5000   60.3000             NaN                NaN
# 40   Time Not Supplied    1.5400    1.6700             NaN                NaN
# 41  Before Market Open       NaN    0.0209             NaN                NaN
# 42                 TAS   32.7000   33.1200             NaN                NaN
# 43  Before Market Open    0.0036    0.0039             NaN                NaN
# 44   Time Not Supplied       NaN    5.9200             NaN                NaN
# 45   Time Not Supplied    0.0010    0.0010             NaN                NaN
# 46   Time Not Supplied       NaN    0.0145             NaN                NaN
# 47                 TAS    4.5000    4.3600             NaN                NaN
# 48  After Market Close       NaN       NaN             NaN                NaN
# 49   Time Not Supplied       NaN    0.0124             NaN                NaN
# 50  Before Market Open   31.6800   31.0100             NaN                NaN
# 51   Time Not Supplied       NaN       NaN             NaN                NaN
# 52   Time Not Supplied       NaN       NaN             NaN                NaN
# 53   Time Not Supplied       NaN    0.0377             NaN                NaN
# 54  Before Market Open       NaN    0.3225             NaN                NaN
# 55   Time Not Supplied    0.7000    0.5500             NaN                NaN
# 56  Before Market Open    0.0300    0.0290             NaN                NaN
#
#     PutFridayOpenInterest  CallFridayOpenInterest  Expected_Range
# 0                     0.0                     0.0             NaN
# 1                     0.0                     0.0             NaN
# 2                     0.0                     0.0             NaN
# 3                     0.0                     0.0             NaN
# 4                     0.0                     0.0             NaN
# 5                     0.0                     0.0             NaN
# 6                     0.0                     0.0             NaN
# 7                    12.0                     9.0             NaN
# 8                     0.0                     0.0             NaN
# 9                     0.0                     0.0             NaN
# 10                16555.0                  6350.0             NaN
# 11                    0.0                     0.0             NaN
# 12                    0.0                     0.0             NaN
# 13                    0.0                     0.0             NaN
# 14                    0.0                     0.0             NaN
# 15                    0.0                     0.0             NaN
# 16                    0.0                     0.0             NaN
# 17                    0.0                     0.0             NaN
# 18                  396.0                   206.0             NaN
# 19                    0.0                     0.0             NaN
# 20                10431.0                 11971.0             NaN
# 21                    0.0                     0.0             NaN
# 22                 2382.0                  4161.0             NaN
# 23                15915.0                  1615.0            0.61
# 24                  414.0                    64.0             NaN
# 25                    0.0                     0.0             NaN
# 26                  750.0                  1077.0             NaN
# 27                  109.0                    13.0             NaN
# 28                    0.0                     0.0             NaN
# 29                    0.0                     0.0             NaN
# 30                    0.0                     0.0             NaN
# 31                14845.0                  9637.0             NaN
# 32                    0.0                     0.0             NaN
# 33                    0.0                     0.0             NaN
# 34                    0.0                     0.0             NaN
# 35                  254.0                    67.0             NaN
# 36                   20.0                     0.0             NaN
# 37                    0.0                     0.0             NaN
# 38                   74.0                   147.0             NaN
# 39                    0.0                     0.0             NaN
# 40                    0.0                     0.0             NaN
# 41                    0.0                     0.0             NaN
# 42                    0.0                     0.0             NaN
# 43                    0.0                     0.0             NaN
# 44                    0.0                     0.0             NaN
# 45                    0.0                     0.0             NaN
# 46                    0.0                     0.0             NaN
# 47                  406.0                    16.0             NaN
# 48                    0.0                     0.0             NaN
# 49                    0.0                     0.0             NaN
# 50                 2600.0                  6836.0             NaN
# 51                    0.0                     0.0             NaN
# 52                    0.0                     0.0             NaN
# 53                    0.0                     0.0             NaN
# 54                    0.0                     0.0             NaN
# 55                    0.0                     0.0             NaN
# 56                    0.0                     0.0             NaN

# %%
buildCsvSummary.saveCsvSummary(earningsDF, earningsDFAll, startday)
